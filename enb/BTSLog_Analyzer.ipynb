# %% [markdown]
# ## BTSLOG分析脚本
# ---
# **环境**：
# - Python 3.5+
#
# **功能**
# - 根据自定义规则过滤BTSLog
#
# **历史**
# - 0.01: 2016/09/30

# %%
import os
import re
import glob
import time

# 读取文件返回文件每一行
def lines(file):
    for line in file:
        yield line

# 获取SYSLOG列表
def filelist(path):
    os.chdir(path)
    file_list = glob.glob(r"./SYSLOG_*.LOG")
    return file_list

# Parser类
class Parser:
    def __init__(self):
        self.rules = []
        self.start_rule = ""
        self.end_rule = ""
        self.start_flag = False  # once start point matched, set this flag to true
        self.end_flag = False    # once end point matched, set this flag to false
        self.mid_flag = False    # the reason to introduce this flag is to print the last line which is matched with end point

    # 设置log分析的起始点和结束点    
    def setFilter(self, start_rule=r'.*', end_rule=r'^9999999999999'):
        'Set start point and end point which are for pasring'
        self.start_rule = start_rule
        self.end_rule = end_rule
    
    # 只解析起始点和结束点之间的log，所以要找到log中的起始点和结束点并标记
    def applyFilter(self, line):
        'Only to parse the logs between start point and end point'
        if self.mid_flag:
            self.end_flag = True
        if not self.start_flag:
            start = re.search(self.start_rule, line)
            if start:
                self.start_flag = True
        
        if (self.start_flag) and (not self.end_flag):
            end = re.search(self.end_rule, line)
            if end:
                self.mid_flag = True
    
    # 正则表达式表示的过滤规则
    def addRule(self, rule):
        'add reg pattern'
        self.rules.append(rule) 
    
    # 对Log应用过滤规则
    def applyRule(self, line):
        'apply reg pattern for paring log'
        # 如果Log中一行匹配多了个rule，为了避免重复打印，设置flag
        flag = False        
        for rule in self.rules:
            if not flag:
                search_result = re.search(rule, line, re.I|re.M)
                if (search_result):
                    flag = True
                    print(line.strip())     
    
    # 根据规则解析Log
    def parse(self, file):
        'parsing logs between start point and end point as configured'
        for line in lines(file):
            self.applyFilter(line)
            if (self.start_flag) and (not self.end_flag):
                self.applyRule(line)
        
        # set these flag to initial value for next log parsing
        self.start_flag = False
        self.end_flag = False
        self.mid_flag = False

# BTSLog解析子类
class BTSLogParser(Parser):
    def __init__(self):
        Parser.__init__(self)

# %%
LOG_PATH = r'D:\userdata\anliu\Desktop\log\BTSLogs' 

parser = BTSLogParser()  
parser.addRule(r'MAC_USER_DELETE')
parser.addRule(r'UecUeRelease')

# set start point and end point
start_point = r".*"
end_point = r'^020000'
parser.setFilter(start_point,end_point)

flist = filelist(LOG_PATH)
for file in flist:      
    print("Parsing log '%s' started......" %file.split("\\")[1])
    print("*"*60)
    with open(file) as f:  
        parser.parse(f)
    print("*"*60)
    print("Parsing Log '%s' completed!\n\n"%file.split('\\')[1])
# Out:
# Parsing log 'SYSLOG_190.LOG' started......
# ************************************************************
# 007838 08.09 21:30:35.959  [192.168.255.129]  a7 FSP-2273 <2004-01-01T00:20:39.096803Z> 13-EmDispatch INF/LTE L2/L2Manager/cBr6EDFu628x6ElF/MAC_USER_DELETE_REQ: ueId=1576, cellId=11
# 007954 08.09 21:30:35.975  [192.168.255.129]  fc FSP-220D-6-UECexe <2004-01-01T00:20:39.081520Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#1122 [ueContextId:1576 cellId:35851] StateIdle() payLoadId:0x3110
# 007955 08.09 21:30:35.975  [192.168.255.129]  fd FSP-220D-6-UECexe <2004-01-01T00:20:39.081538Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#735 [ueContextId:1576 cellId:35851] validateUeConnectionRelease() payloadId:UEC_UEM_UE_CONNECTION_RELEASE cellId:35851 releaseReason:13
# 007994 08.09 21:30:35.990  [192.168.255.129]  03 FSP-220D-6-UECexe <2004-01-01T00:20:39.081618Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#854 [ueContextId:1576 cellId:35851] sendS1ApUeContextReleaseRequest() forwardEvent: TUP_SGNLNW_PORT, payLoadId:TUPC_L3S1_MESSAGE_REQ_MSG asn1PayloadId:S1AP_UE_CONTEXT_RELEASE_REQUEST discS1apCause:0 s1apCause:??INVALID_ES1apCauseMisc [0x15]
# 008006 08.09 21:30:35.990  [192.168.255.129]  0f FSP-220D-6-UECexe <2004-01-01T00:20:39.082050Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#1405 [ueContextId:1576 cellId:35851] StateIdle() started timer tUeContextReleaseReq[ms]:5000 timerId:2017 nextState->StateWaitForUeContextReleaseCommand
# 008061 08.09 21:30:35.990  [192.168.255.129]  29 FSP-220D-6-UECexe <2004-01-01T00:20:39.094660Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#1681 [ueContextId:1576 cellId:35851] stopped s1ApMsgRespTimerId:2017
# 008062 08.09 21:30:35.990  [192.168.255.129]  2a FSP-220D-6-UECexe <2004-01-01T00:20:39.094673Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#573 [ueContextId:1576 cellId:35851] validateTupL3MessageWithUeContextReleaseCommand() ueContextId:1576 payloadId:TUPC_L3S1_MESSAGE_IND_MSG linkId:2
# 008063 08.09 21:30:35.990  [192.168.255.129]  2b FSP-220D-6-UECexe <2004-01-01T00:20:39.094689Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#474 [ueContextId:1576 cellId:35851] handleS1ApUeContextReleaseCommand() asn1PayloadId:S1AP_UE_CONTEXT_RELEASE_COMMAND discriminator:0 uES1APIDPair.mMEUES1APID:209787 uES1APIDPair.eNBUES1APID:20 cause.discriminator:0 cause:21
# 008069 08.09 21:30:35.990  [192.168.255.129]  2f FSP-220D-6-UECexe <2004-01-01T00:20:39.094760Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#309 [ueContextId:1576 cellId:35851] tryToSendRrcRelease(): isRrcConnected: 1
# 008071 08.09 21:30:35.990  [192.168.255.129]  31 FSP-220D-6-UECexe <2004-01-01T00:20:39.094809Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#967 [ueContextId:1576 cellId:35851] forwardEvent:TUP_SGNLSRB_PORT, payLoadId:TUP_SRB_SEND_REQ_MSG asn1PayloadId:RRC_CONNECTION_RELEASE
# 008110 08.09 21:30:36.06  [192.168.255.129]  3e FSP-220D-6-UECexe <2004-01-01T00:20:39.095345Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#925 [ueContextId:1576 cellId:35851] Timer TL2AckRrcRel started with time [ms]: 70000 timerId:2018 ueContextId:1576
# 008151 08.09 21:30:36.22  [192.168.255.129]  4e FSP-220D-6-UECexe <2004-01-01T00:20:39.095818Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#355 [ueContextId:1576 cellId:35851] StateIdle() nextState->stateWaitForTupSrbSendResponse
# 008166 08.09 21:30:36.22  [192.168.255.129]  5b FSP-220D-6-UECexe <2004-01-01T00:20:39.096149Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#597 [ueContextId:1576 cellId:35851] payloadId: TUP_SRB_SEND_RESP_MSG lnCellId:11 crnti:28383 status:1
# 008167 08.09 21:30:36.22  [192.168.255.129]  5c FSP-220D-6-UECexe <2004-01-01T00:20:39.096161Z> D34-EuUec::UeContex WRN/UEC/UecUeRelease.cpp#642 [ueContextId:1576 cellId:35851] handleTupSrbSendResponse() negative response from TUP_L3MessageReq status:1 cause:0 specificCause:1
# 008171 08.09 21:30:36.22  [192.168.255.129]  60 FSP-220D-6-UECexe <2004-01-01T00:20:39.096204Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#1674 [ueContextId:1576 cellId:35851] stopped rrcMsgRespTimerId:2018
# 008172 08.09 21:30:36.22  [192.168.255.129]  61 FSP-220D-6-UECexe <2004-01-01T00:20:39.096221Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#990 [ueContextId:1576 cellId:35851] sendUecCtyUeConnectivityRelease() ->serviceProcessEvent() payLoadId:UEC_CTY_UE_CONNECTIVITY_RELEASE
# 008268 08.09 21:30:36.37  [192.168.255.129]  87 FSP-220D-6-UECexe <2004-01-01T00:20:39.096928Z> D34-EuUec::UeContex DBG/UEC/UecConnectivityMac.cpp#1450 [ueContextId:1576 cellId:35851] stateIdle() payLoadId:UEC_CTY_MAC_USER_DELETE validUeContextId:1
# 008271 08.09 21:30:36.37  [192.168.255.129]  8a FSP-220D-6-UECexe <2004-01-01T00:20:39.096989Z> D34-EuUec::UeContex DBG/UEC/UecConnectivityMac.cpp#888 [ueContextId:1576 cellId:35851] sendMacUserDeleteRequest() forwardEvent to MAC_USER_PORT payLoadId:MAC_USER_DELETE_REQ_MSG cellId:35851 uplaneCellId:11 crnti:28383
# 008365 08.09 21:30:36.53  [192.168.255.129]  b0 FSP-220D-6-UECexe <2004-01-01T00:20:39.108920Z> D34-EuUec::UeContex DBG/UEC/UecConnectivityMac.cpp#436 [ueContextId:1576 cellId:35851] handleMacUserDeleteResponse() payLoadId:MAC_USER_DELETE_RESP_MSG status:0 cellId:35851 uplaneCellId:11 crnti:28383
# 008378 08.09 21:30:36.53  [192.168.255.129]  bd FSP-220D-6-UECexe <2004-01-01T00:20:39.109180Z> D34-EuUec::UeContex DBG/UEC/UecGenNotifyHandler.hpp#54 Handle GenNotify. Service: UecUeRelease. Current state: StateWaitForUecCtyUeConnectivityReleaseNotify, Status: BASE_SUCCESS
# 008427 08.09 21:30:36.68  [192.168.255.129]  cd FSP-220D-6-UECexe <2004-01-01T00:20:39.109503Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#2153 [ueContextId:1576 cellId:35851] StateWaitForUecCtyUeConnectivityReleaseNotify() nextState->StateWaitForUecResDeAllocationNotify
# 008531 08.09 21:30:36.84  [192.168.255.129]  01 FSP-220D-6-UECexe <2004-01-01T00:20:39.110592Z> D34-EuUec::UeContex DBG/UEC/UecGenNotifyHandler.hpp#54 Handle GenNotify. Service: UecUeRelease. Current state: StateWaitForUecResDeAllocationNotify, Status: BASE_SUCCESS
# 008613 08.09 21:30:36.100  [192.168.255.129]  2b FSP-220D-6-UECexe <2004-01-01T00:20:39.111237Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#1732 [ueContextId:1576] finishService(): nextState->StateIdle.
# 016662 08.09 21:30:37.847  [192.168.255.129]  c7 FSP-220D-6-UECexe <2004-01-01T00:20:40.398371Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#1122 [ueContextId:1587 cellId:35851] StateIdle() payLoadId:0x27dd
# 016663 08.09 21:30:37.847  [192.168.255.129]  c8 FSP-220D-6-UECexe <2004-01-01T00:20:40.398392Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#573 [ueContextId:1587 cellId:35851] validateTupL3MessageWithUeContextReleaseCommand() ueContextId:1587 payloadId:TUPC_L3S1_MESSAGE_IND_MSG linkId:2
# 016664 08.09 21:30:37.847  [192.168.255.129]  c9 FSP-220D-6-UECexe <2004-01-01T00:20:40.398409Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#474 [ueContextId:1587 cellId:35851] handleS1ApUeContextReleaseCommand() asn1PayloadId:S1AP_UE_CONTEXT_RELEASE_COMMAND discriminator:0 uES1APIDPair.mMEUES1APID:209920 uES1APIDPair.eNBUES1APID:60 cause.discriminator:2 cause:3
# 016665 08.09 21:30:37.847  [192.168.255.129]  ca FSP-220D-6-UECexe <2004-01-01T00:20:40.398426Z> D34-EuUec::UeContex DBG/UEC/UecUeReleaseNarrowbandCellPmCounters.cpp#30 [ueContextId:1587 cellId:35851] updatePmCountersForEpcInitiatedTransitionsToEcmIdle() cause.discriminator:2 cause:nas: ES1apCauseNas_Unspecified
# 016668 08.09 21:30:37.847  [192.168.255.129]  cd FSP-220D-6-UECexe <2004-01-01T00:20:40.398497Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#385 [ueContextId:1587 cellId:35851] StateIdle() nextState->s_stateWaitForDirectTransferNotification
# 016674 08.09 21:30:37.847  [192.168.255.129]  d3 FSP-220D-6-UECexe <2004-01-01T00:20:40.398603Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#2055 [ueContextId:1587 cellId:35851] Event received, payLoadId= 0x3100, releaseReason= 27.
# 016675 08.09 21:30:37.847  [192.168.255.129]  d4 FSP-220D-6-UECexe <2004-01-01T00:20:40.398615Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#2081 [ueContextId:1587 cellId:35851] Sending RrcConnectionRelease because isRrcConnected
# 016677 08.09 21:30:37.847  [192.168.255.129]  d6 FSP-220D-6-UECexe <2004-01-01T00:20:40.398662Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#967 [ueContextId:1587 cellId:35851] forwardEvent:TUP_SGNLSRB_PORT, payLoadId:TUP_SRB_SEND_REQ_MSG asn1PayloadId:RRC_CONNECTION_RELEASE
# 016718 08.09 21:30:37.862  [192.168.255.129]  e3 FSP-220D-6-UECexe <2004-01-01T00:20:40.399164Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#925 [ueContextId:1587 cellId:35851] Timer TL2AckRrcRel started with time [ms]: 70000 timerId:2041 ueContextId:1587
# 016720 08.09 21:30:37.862  [192.168.255.129]  e5 FSP-220D-6-UECexe <2004-01-01T00:20:40.399199Z> D34-EuUec::UeContex DBG/UEC/UecUeRelease.cpp#2092 [ueContextId:1587 cellId:35851] StateIdle() nextState->stateWaitForTupSrbSendResponse
# ************************************************************
# Parsing Log 'SYSLOG_190.LOG' completed!
